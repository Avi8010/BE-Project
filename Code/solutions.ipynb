# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('internships_final.csv')

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                 job_title
# 0             0           0       iOS App Development  \
# 1             1           1  Internet Of Things (IoT)
# 2             2           2        Product Management
# 3             3           3           Web Development
# 4             4           4           Web Development
#
#                           company_name        location
# 0                            STEMpedia       Ahmedabad  \
# 1  Purewatt Renewables Private Limited         Gunupur
# 2     FynTune Solution Private Limited           Thane
# 3          Space Chase Private Limited  Work From Home
# 4                        Digital Yodha  Work From Home
#
#                    salary                                        description
# 0   ₹ 9,000-15,000 /month  Selected intern's day-to-day responsibilities ...  \
# 1         ₹ 10,000 /month  Selected intern's day-to-day responsibilities ...
# ...

# %%
print("true are ", (df['authentic']==1).sum())
print("fake are", (df['authentic']==0).sum())
# Out:
# true are  329
# fake are 765

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'job_title', 'company_name', 'location',
#        'salary', 'description', 'company_description', 'hired_to_posted_ratio',
#        'has_company_logo', 'job_description_length', 'Important_Word_Count',
#        'important_words', 'currency_in_title', 'authentic', 'htp_ratio'],
#       dtype='object')

# %%
df=df.drop(columns=(['Unnamed: 0','Unnamed: 0.1']))

# %%
df.to_csv('internshala_final.csv', mode='w', index=False, header=False)

# %%
df2=pd.read_csv('internshala_final.csv')

# %%
df2
# Out:
#                      job_title                                   company_name
# 0          iOS App Development                                      STEMpedia  \
# 1     Internet Of Things (IoT)            Purewatt Renewables Private Limited
# 2           Product Management               FynTune Solution Private Limited
# 3              Web Development                    Space Chase Private Limited
# 4              Web Development                                  Digital Yodha
# ...                        ...                                            ...
# 1089  Software Testing Trainer   Techeir/Konseptrix Analytics Private Limited
# 1090            Java Developer                                       ISOCONIC
# 1091       Azure Data Engineer                                    Blackcoffer
# 1092        Core PHP Developer                                    Blackcoffer
# 1093             PHP Developer  NexGen Innovators IT Services Private Limited
#
# ...

# %%
df3=df[df.columns[5:14]]
df3
# Out:
#       company_description  hired_to_posted_ratio  has_company_logo
# 0                       1               2.733871                 1  \
# 1                       1               3.000000                 1
# 2                       1               2.548387                 1
# 3                       1               0.000000                 1
# 4                       1               3.000000                 1
# ...                   ...                    ...               ...
# 1089                    1              53.000000                 1
# 1090                    1               0.000000                 1
# 1091                    1               2.089406                 1
# 1092                    1               2.089406                 1
# 1093                    1               0.000000                 1
#
#       job_description_length  Important_Word_Count  important_words
# 0                          1                     3                1  \
# ...

# %%
df4=df3['authentic']
df3=df3.drop(columns=['authentic'])

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(df3, df4, test_size=0.2, random_state=22)

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(X_train, y_train)
y_pred = rf_classifier.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

# %%
print(f"Accuracy: {accuracy:.2f}")
print("\nClassification Report:\n", classification_rep)
# Out:
# Accuracy: 1.00*100
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       146
#            1       1.00      1.00      1.00        73
#
#     accuracy                           1.00       219
#    macro avg       1.00      1.00      1.00       219
# weighted avg       1.00      1.00      1.00       219

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(14,14))
sns.heatmap(data=df3)
# Out:
# <Axes: >
