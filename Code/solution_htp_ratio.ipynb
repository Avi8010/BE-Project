# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('internships_internshala1.csv')

# %%
df.columns
# Out:
# Index(['job_title', 'company_name', 'location', 'salary', 'description',
#        'company_description', 'hired_to_posted_ratio', 'has_company_logo',
#        'job_description_length'],
#       dtype='object')

# %%
df.head()
# Out:
#                   job_title                         company_name
# 0       iOS App Development                            STEMpedia  \
# 1  Internet Of Things (IoT)  Purewatt Renewables Private Limited
# 2        Product Management     FynTune Solution Private Limited
# 3           Web Development          Space Chase Private Limited
# 4           Web Development                        Digital Yodha
#
#          location                  salary
# 0       Ahmedabad   ₹ 9,000-15,000 /month  \
# 1         Gunupur         ₹ 10,000 /month
# 2           Thane  ₹ 12,000-18,000 /month
# 3  Work From Home          ₹ 5,000 /month
# 4  Work From Home          ₹ 1,500 /month
#
#                                          description  company_description
# 0  Selected intern's day-to-day responsibilities ...                    1  \
# 1  Selected intern's day-to-day responsibilities ...                    1
# 2  Selected intern's day-to-day responsibilities ...                    1
# ...

# %%
df['hired_to_posted_ratio']=pd.to_numeric(df['hired_to_posted_ratio'], downcast='float')

# %%
df.head()
# Out:
#                   job_title                         company_name
# 0       iOS App Development                            STEMpedia  \
# 1  Internet Of Things (IoT)  Purewatt Renewables Private Limited
# 2        Product Management     FynTune Solution Private Limited
# 3           Web Development          Space Chase Private Limited
# 4           Web Development                        Digital Yodha
#
#          location                  salary
# 0       Ahmedabad   ₹ 9,000-15,000 /month  \
# 1         Gunupur         ₹ 10,000 /month
# 2           Thane  ₹ 12,000-18,000 /month
# 3  Work From Home          ₹ 5,000 /month
# 4  Work From Home          ₹ 1,500 /month
#
#                                          description  company_description
# 0  Selected intern's day-to-day responsibilities ...                    1  \
# 1  Selected intern's day-to-day responsibilities ...                    1
# 2  Selected intern's day-to-day responsibilities ...                    1
# ...

# %%
m=np.mean(df['hired_to_posted_ratio'])
print(m)
# Out:
# 25.226477

# %%
hp_ratio=df['hired_to_posted_ratio']

# %%
htp_ratio=[]
for i in range(0,len(hp_ratio)) :
    if hp_ratio[i]>=0.25 and hp_ratio[i]<=10 :
        htp_ratio.append(1)
    else:
        htp_ratio.append(0)

# %%
print("true : ",htp_ratio.count(1))
print("false :",htp_ratio.count(0))
# Out:
# true :  417
# false : 677

# %%
df.insert(7,'htp_ratio',htp_ratio)

# %%
df.head()
# Out:
#                   job_title                         company_name
# 0       iOS App Development                            STEMpedia  \
# 1  Internet Of Things (IoT)  Purewatt Renewables Private Limited
# 2        Product Management     FynTune Solution Private Limited
# 3           Web Development          Space Chase Private Limited
# 4           Web Development                        Digital Yodha
#
#          location                  salary
# 0       Ahmedabad   ₹ 9,000-15,000 /month  \
# 1         Gunupur         ₹ 10,000 /month
# 2           Thane  ₹ 12,000-18,000 /month
# 3  Work From Home          ₹ 5,000 /month
# 4  Work From Home          ₹ 1,500 /month
#
#                                          description  company_description
# 0  Selected intern's day-to-day responsibilities ...                    1  \
# 1  Selected intern's day-to-day responsibilities ...                    1
# 2  Selected intern's day-to-day responsibilities ...                    1
# ...
